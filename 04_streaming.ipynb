# %%
from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"
assistant_messages = []

def add_user_message(messages, text):
    user_message = ({"role": "user", "content": text})
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = ({"role": "assistant", "content": text})
    messages.append(assistant_message)

# %%
# make a starting list of messages
messages = []

add_user_message(messages, "Generate a one sentence description of a fake database.")
stream = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
    stream=True
)

for event in stream:
    print(event)
# Out:
# RawMessageStartEvent(message=Message(id='msg_016qGaAFTwyv6f6KBSniKK1f', container=None, content=[], model='claude-sonnet-4-20250514', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=2, server_tool_use=None, service_tier='standard')), type='message_start')
# RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='A comprehensive', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' database containing detailed psychological profiles, spending habits, and daily routines of over 50 million fictional', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' residents from the imaginary city of Meridian Falls, organized by', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' neighborhood districts and updated in real-time through simulated social media activity.', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockStopEvent(index=0, type='content_block_stop')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=17, output_tokens=54, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')

# %%
# make a starting list of messages
messages = []

add_user_message(messages, "Generate a one sentence description of a fake database.")
with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages,
) as stream:
    for text in stream.text_stream:
        # print(text, end="")
        pass
    
final = stream.get_final_message()
final
# Out:
# ParsedMessage(id='msg_01PMb1iAHW9jmSG2k2AqLWea', container=None, content=[ParsedTextBlock(citations=None, text='A comprehensive repository containing detailed psychological profiles, purchasing habits, and social network connections for over 50 million fictional residents of the imaginary nation of Zelantia.', type='text', parsed_output=None)], model='claude-sonnet-4-20250514', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=37, server_tool_use=None, service_tier='standard'))

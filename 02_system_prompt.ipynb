# %%
from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"
assistant_messages = []

def add_user_message(messages, text):
    user_message = ({"role": "user", "content": text})
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = ({"role": "assistant", "content": text})
    messages.append(assistant_message)
    
def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system is not None:
        params["system"] = system
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# make a starting list of messages
messages = []
system = """
You are a python engineering assistant.
When answering the question provide code that is as concise as possible. Suggest only one solution to the problem.
Only provide the code, nothing else.
"""

add_user_message(messages, "Write a python function that checks for duplication characters in a string.")
answer = chat(messages, system=system)
# answer = chat(messages=messages)
answer
# Out:
# '```python\ndef has_duplicate_chars(s):\n    return len(s) != len(set(s))\n```'
